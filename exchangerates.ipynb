# %%
import pandas as pd
import numpy as np

# %%
exchange_rates = pd.read_csv("euro-daily-hist_1999_2022.csv")

# %%
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-05-26               1.6439           1.9558            5.3878
# 1   2023-05-25               1.6443           1.9558            5.3320
# 2   2023-05-24               1.6402           1.9558            5.3397
# 3   2023-05-23               1.6282           1.9558            5.3649
# 4   2023-05-22               1.6294           1.9558            5.4056
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4630         0.9707                   7.5874              NaN
# 1             1.4599         0.9708                   7.5891              NaN
# 2             1.4600         0.9732                   7.6005              NaN
# 3             1.4571         0.9718                   7.6039              NaN
# 4             1.4618         0.9700                   7.6067              NaN
#
# ...

# %%
exchange_rates.tail(10)
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6301   1999-01-15               1.8388              NaN               NaN
# 6302   1999-01-14               1.8353              NaN               NaN
# 6303   1999-01-13               1.8620              NaN               NaN
# 6304   1999-01-12               1.8090              NaN               NaN
# 6305   1999-01-11               1.8134              NaN               NaN
# 6306   1999-01-08               1.8406              NaN               NaN
# 6307   1999-01-07               1.8474              NaN               NaN
# 6308   1999-01-06               1.8820              NaN               NaN
# 6309   1999-01-05               1.8944              NaN               NaN
# 6310   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6301             1.7797         1.5984                      NaN
# ...

# %%
exchange_rates
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0      2023-05-26               1.6439           1.9558            5.3878
# 1      2023-05-25               1.6443           1.9558            5.3320
# 2      2023-05-24               1.6402           1.9558            5.3397
# 3      2023-05-23               1.6282           1.9558            5.3649
# 4      2023-05-22               1.6294           1.9558            5.4056
# ...           ...                  ...              ...               ...
# 6306   1999-01-08               1.8406              NaN               NaN
# 6307   1999-01-07               1.8474              NaN               NaN
# 6308   1999-01-06               1.8820              NaN               NaN
# 6309   1999-01-05               1.8944              NaN               NaN
# 6310   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# ...

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6311 non-null   object
#  1   [Australian dollar ]      6311 non-null   object
#  2   [Bulgarian lev ]          5909 non-null   object
#  3   [Brazilian real ]         6043 non-null   object
#  4   [Canadian dollar ]        6311 non-null   object
#  5   [Swiss franc ]            6311 non-null   object
#  6   [Chinese yuan renminbi ]  6043 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6311 non-null   object
#  9   [Danish krone ]           6311 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6311 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %%
exchange_rates = exchange_rates.rename(columns={
    '[US dollar ]': 'US_dollar',
    'Period\\Unit:': 'Time',
    '[Polish zloty ]': 'PLN',
})

# %%
exchange_rates.columns
# Out:
# Index(['Time', '[Australian dollar ]', '[Bulgarian lev ]', '[Brazilian real ]',
#        '[Canadian dollar ]', '[Swiss franc ]', '[Chinese yuan renminbi ]',
#        '[Cypriot pound ]', '[Czech koruna ]', '[Danish krone ]',
#        '[Estonian kroon ]', '[UK pound sterling ]', '[Greek drachma ]',
#        '[Hong Kong dollar ]', '[Croatian kuna ]', '[Hungarian forint ]',
#        '[Indonesian rupiah ]', '[Israeli shekel ]', '[Indian rupee ]',
#        '[Iceland krona ]', '[Japanese yen ]', '[Korean won ]',
#        '[Lithuanian litas ]', '[Latvian lats ]', '[Maltese lira ]',
#        '[Mexican peso ]', '[Malaysian ringgit ]', '[Norwegian krone ]',
#        '[New Zealand dollar ]', '[Philippine peso ]', 'PLN', '[Romanian leu ]',
#        '[Russian rouble ]', '[Swedish krona ]', '[Singapore dollar ]',
#        '[Slovenian tolar ]', '[Slovak koruna ]', '[Thai baht ]',
#        '[Turkish lira ]', 'US_dollar', '[South African rand ]'],
#       dtype='object')

# %%
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])

# %%
exchange_rates.sort_values('Time')
# Out:
#            Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6310 1999-01-04               1.9100              NaN               NaN
# 6309 1999-01-05               1.8944              NaN               NaN
# 6308 1999-01-06               1.8820              NaN               NaN
# 6307 1999-01-07               1.8474              NaN               NaN
# 6306 1999-01-08               1.8406              NaN               NaN
# ...         ...                  ...              ...               ...
# 4    2023-05-22               1.6294           1.9558            5.4056
# 3    2023-05-23               1.6282           1.9558            5.3649
# 2    2023-05-24               1.6402           1.9558            5.3397
# 1    2023-05-25               1.6443           1.9558            5.3320
# 0    2023-05-26               1.6439           1.9558            5.3878
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# ...

# %%
exchange_rates.reset_index(drop=True)
# Out:
#            Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0    2023-05-26               1.6439           1.9558            5.3878
# 1    2023-05-25               1.6443           1.9558            5.3320
# 2    2023-05-24               1.6402           1.9558            5.3397
# 3    2023-05-23               1.6282           1.9558            5.3649
# 4    2023-05-22               1.6294           1.9558            5.4056
# ...         ...                  ...              ...               ...
# 6306 1999-01-08               1.8406              NaN               NaN
# 6307 1999-01-07               1.8474              NaN               NaN
# 6308 1999-01-06               1.8820              NaN               NaN
# 6309 1999-01-05               1.8944              NaN               NaN
# 6310 1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# ...

# %%
exchange_rates["US_dollar"].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1268     7
#           ..
# 1.4211     1
# 1.4194     1
# 1.3951     1
# 1.3948     1
# 1.1659     1
# Name: US_dollar, Length: 3734, dtype: int64

# %%
euro_to_dollar = exchange_rates[["Time","US_dollar"]]
euro_to_dollar.head(5)
# Out:
#         Time US_dollar
# 0 2023-05-26    1.0751
# 1 2023-05-25    1.0735
# 2 2023-05-24    1.0785
# 3 2023-05-23    1.0779
# 4 2023-05-22    1.0822

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'].str.contains("-") == False]

# %%
euro_to_dollar["US_dollar"].value_counts()
# Out:
# 1.2276    9
# 1.1215    8
# 1.1268    7
# 1.1305    7
# 1.1346    6
#          ..
# 1.4211    1
# 1.4194    1
# 1.3951    1
# 1.3948    1
# 1.1659    1
# Name: US_dollar, Length: 3733, dtype: int64

# %%
euro_to_dollar["US_dollar"] = euro_to_dollar["US_dollar"].astype(float)

# %%
euro_to_dollar.dtypes
# Out:
# Time         datetime64[ns]
# US_dollar           float64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(euro_to_dollar["Time"],
         euro_to_dollar["US_dollar"])
plt.show()

# %%
euro_to_dollar["rolling_mean"] = euro_to_dollar["US_dollar"].rolling(60).mean()

# %%
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    2023-05-26     1.0751           NaN
# 1    2023-05-25     1.0735           NaN
# 2    2023-05-24     1.0785           NaN
# 3    2023-05-23     1.0779           NaN
# 4    2023-05-22     1.0822           NaN
# ...         ...        ...           ...
# 6306 1999-01-08     1.1659      1.117392
# 6307 1999-01-07     1.1632      1.118825
# 6308 1999-01-06     1.1743      1.120493
# 6309 1999-01-05     1.1790      1.122292
# 6310 1999-01-04     1.1789      1.124120
#
# [6249 rows x 3 columns]

# %%
plt.plot(euro_to_dollar["Time"],
         euro_to_dollar["rolling_mean"])
plt.show()

# %%
pandemic_time = euro_to_dollar[(euro_to_dollar['Time'] >= '2019-10-01') & (euro_to_dollar['Time'] <= '2024-12-31')]

# %%
pandemic_time
# Out:
#           Time  US_dollar  rolling_mean
# 0   2023-05-26     1.0751           NaN
# 1   2023-05-25     1.0735           NaN
# 2   2023-05-24     1.0785           NaN
# 3   2023-05-23     1.0779           NaN
# 4   2023-05-22     1.0822           NaN
# ..         ...        ...           ...
# 933 2019-10-07     1.0993      1.107992
# 934 2019-10-04     1.0979      1.107567
# 935 2019-10-03     1.0951      1.107170
# 936 2019-10-02     1.0925      1.106790
# 937 2019-10-01     1.0898      1.106487
#
# [938 rows x 3 columns]

# %%
plt.plot(pandemic_time["Time"],
         pandemic_time["US_dollar"])
